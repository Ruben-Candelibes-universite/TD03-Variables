# %% [markdown]
# # **R1.07 - Fondamentaux de la programmation**

# %% [markdown]
# # **TD03 - Variables globales, variables locales**

# %% [markdown]
# **Activité 1 :**

# %% [markdown]
# <u> Excercice n°1: </u>
